# %%
import pandas as pd

# %%
pip install pandera
# Out:
# Collecting pandera
#   Downloading pandera-0.6.5-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.5 MB/s  eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandera) (20.9)
# Requirement already satisfied: numpy>=1.9.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandera) (1.21.0)
# Collecting typing-inspect>=0.6.0
#   Downloading typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandera) (3.7.4.3)
# Collecting wrapt
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: pandas>=0.25.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandera) (1.2.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from packaging>=20.0->pandera) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.25.3->pandera) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.25.3->pandera) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->pandera) (1.15.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=36142 sha256=d4c08e5a0fe02c6f3817661404b3d1aa846f76b42d70f95f2bd8df36a625dfa7
#   Stored in directory: /home/jovyan/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# Installing collected packages: mypy-extensions, wrapt, typing-inspect, pandera
# Successfully installed mypy-extensions-0.4.3 pandera-0.6.5 typing-inspect-0.7.1 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandera as pa

# %%
valores_ausentes = ['**','###!','####','****','*****','NULL']
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BEL�M            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
# 5            SALVADOR            BA                  NaN     2010-01-06
# 6               COARI            AM                 SBUY     2010-01-07
# 7            CANUTAMA            AM                  NaN     2010-01-09
# 8            CASCAVEL            PR                 SBCA     2010-01-10
# 9       PAR� DE MINAS            MG                  NaN     2010-01-10
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0
# 5        17:53:00                    0
# 6        18:40:00                    0
# 7        12:30:00                    3
# 8        23:15:00                    2
# 9        20:00:00                    0

# %%
schema = pa.DataFrameSchema(
    columns = {
        'codigo_ocorrencia': pa.Column(pa.Int),
        'codigo_ocorrencia2': pa.Column(pa.Int),
        'ocorrencia_classificacao': pa.Column(pa.String),
        'ocorrencia_cidade': pa.Column(pa.String),
        'ocorrencia_uf': pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        'ocorrencia_aerodromo': pa.Column(pa.String, nullable=True),
        'ocorrencia_dia': pa.Column(pa.DateTime),
        'ocorrencia_hora': pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        'ocorrencia_recomendacoes': pa.Column(pa.Int),
    }
                                    )

# %%
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-14-dc85ea979a2b> in <module>
# ----> 1 schema.validate(df)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     538                         msg,
#     539                         failure_cases=scalar_failure_case(colname),
# --> 540                         check="column_in_dataframe",
#     541                     ),
#     542                 )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# SchemaError: column 'ocorrencia_recomendacoes' not in dataframe
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BEL�M            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BEL�M
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BEL�M
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
filtro=df.ocorrencia_hora.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4100              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4100           CORUMB�            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4100             NaN                    0

# %%
#ocorrencia com mais de 10 recomendacoes
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2795              52265               52265                 ACIDENTE
# 3930              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               S�O PAULO            SP                 SBMT     2010-02-17
# 326         RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
# 530              S�O PAULO            SP                  NaN     2010-12-14
# 727               IT�POLIS            SP                 SDIO     2011-04-09
# 872                 RECIFE            PE                 SBRF     2011-07-13
# 884   S�O JOS� DOS PINHAIS            PR                 SBCT     2011-07-15
# 1062            UBERL�NDIA            MG                 SBUL     2011-11-15
# 1972              BRAS�LIA            DF                 SBBR     2013-04-13
# 2795                SANTOS            SP                  NaN     2014-08-13
# 3930               VIT�RIA            ES                  NaN     2017-02-21
#
#      ocorrencia_hora  total_recomendacoes
# 63          20:07:00                   11
# 326         12:26:00                   19
# 530         20:15:00                   11
# 727         14:50:00                   11
# 872         09:54:00                   23
# 884         17:05:00                   11
# 1062        02:15:00                   20
# 1972        18:00:00                   11
# 2795        13:03:00                   13
# 3930        11:47:00                   12

# %%
#ocorrencia com mais de 10 recomendacoes
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               S�O PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              S�O PAULO                   11
# 727               IT�POLIS                   11
# 872                 RECIFE                   23
# 884   S�O JOS� DOS PINHAIS                   11
# 1062            UBERL�NDIA                   20
# 1972              BRAS�LIA                   11
# 2795                SANTOS                   13
# 3930               VIT�RIA                   12

# %%
#ocorrencia cuja classificacao == INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PAR� DE MINAS            MG                  NaN     2010-01-10
# 29             CURITIBA            PR                 SBBI     2010-01-23
# 35               PALMAS            TO                 SBPJ     2010-01-26
# ...                 ...           ...                  ...            ...
# 5741       NOVA MARING�            MT                  NaN     2020-12-28
# 5744           GOIATUBA            GO                  NaN     2020-12-29
# 5746      MANOEL URBANO            AC                 SIMB     2020-12-29
# 5748  LAGOA DA CONFUS�O            TO                  NaN     2020-12-30
# 5750          VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 29          16:36:00                    2
# 35          16:50:00                    0
# ...              ...                  ...
# 5741        13:00:00                    0
# 5744        12:00:00                    0
# 5746        18:30:00                    0
# 5748        18:30:00                    0
# 5750        09:00:00                    0
#
# [737 rows x 9 columns]

# %%
#ocorrencia cuja classificacao == INCIDENTE GRAVE e o estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5591              79540               79540          INCIDENTE GRAVE
# 5610              79566               79566          INCIDENTE GRAVE
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 136            PIRASSUNUNGA            SP                 SDPY     2010-04-15
# 171               GUARULHOS            SP                 SBGR     2010-05-06
# 219               S�O PAULO            SP                 SBMT     2010-06-08
# 297               S�O PAULO            SP                 SBMT     2010-07-29
# 314   S�O JOS� DO RIO PRETO            SP                 SBSR     2010-08-05
# ...                     ...           ...                  ...            ...
# 5591              S�O PAULO            SP                  NaN     2020-09-12
# 5610          REGENTE FEIJ�            SP                 SDYJ     2020-09-27
# 5704              S�O PAULO            SP                 SBSP     2020-12-03
# 5705               SOROCABA            SP                 SDCO     2020-12-04
# 5715              S�O PAULO            SP                 SBMT     2020-12-11
#
#      ocorrencia_hora  total_recomendacoes
# 136         20:15:00                    0
# 171         15:50:00                    0
# 219         19:30:00                    2
# 297         20:06:00                    0
# 314         12:01:00                    0
# ...              ...                  ...
# 5591        13:10:00                    0
# 5610        19:33:00                    0
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
#
# [137 rows x 9 columns]

# %%
#ocorrencia cuja (classificacao == INCIDENTE GRAVE ou classificacao == INCIDENTE) e o estado == SP
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 16           S�O PAULO            SP                  NaN     2010-01-15
# 18              SANTOS            SP                  NaN     2010-01-15
# 26            SOROCABA            SP                  NaN     2010-01-20
# 27            CAMPINAS            SP                  NaN     2010-01-21
# 33           GUARULHOS            SP                 SBGR     2010-01-25
# ...                ...           ...                  ...            ...
# 5704         S�O PAULO            SP                 SBSP     2020-12-03
# 5705          SOROCABA            SP                 SDCO     2020-12-04
# 5715         S�O PAULO            SP                 SBMT     2020-12-11
# 5742         S�O PAULO            SP                 SBMT     2020-12-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 16          15:00:00                    0
# 18          17:45:00                    0
# 26          13:10:00                    0
# 27          20:45:00                    0
# 33          17:05:00                    0
# ...              ...                  ...
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
# 5742        10:15:00                    0
# 5747        19:00:00                    0
#
# [985 rows x 9 columns]

# %%
#ocorrencia cuja (classificacao == INCIDENTE GRAVE ou classificacao == INCIDENTE) e o estado == SP
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE','INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 16           S�O PAULO            SP                  NaN     2010-01-15
# 18              SANTOS            SP                  NaN     2010-01-15
# 26            SOROCABA            SP                  NaN     2010-01-20
# 27            CAMPINAS            SP                  NaN     2010-01-21
# 33           GUARULHOS            SP                 SBGR     2010-01-25
# ...                ...           ...                  ...            ...
# 5704         S�O PAULO            SP                 SBSP     2020-12-03
# 5705          SOROCABA            SP                 SDCO     2020-12-04
# 5715         S�O PAULO            SP                 SBMT     2020-12-11
# 5742         S�O PAULO            SP                 SBMT     2020-12-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 16          15:00:00                    0
# 18          17:45:00                    0
# 26          13:10:00                    0
# 27          20:45:00                    0
# 33          17:05:00                    0
# ...              ...                  ...
# 5704        14:42:00                    0
# 5705        15:30:00                    0
# 5715        13:50:00                    0
# 5742        10:15:00                    0
# 5747        19:00:00                    0
#
# [985 rows x 9 columns]

# %%
#ocorrencia cuja cidade comecem com a letra C
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 5661              79649               79649                INCIDENTE
# 5663              79652               79652                INCIDENTE
# 5680              79683               79683                INCIDENTE
# 5696              79692               79692                 ACIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6                COARI            AM                 SBUY     2010-01-07
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 8             CASCAVEL            PR                 SBCA     2010-01-10
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 20     CRUZEIRO DO SUL            AC                 SBCZ     2010-01-18
# ...                ...           ...                  ...            ...
# 5661          CAMPINAS            SP                 SBKP     2020-11-04
# 5663           CONFINS            MG                 SBCF     2020-11-06
# 5680   CRUZEIRO DO SUL            AC                 SBCZ     2020-11-16
# 5696         CATANDUVA            SP                 SDCD     2020-11-28
# 5747          CAMPINAS            SP                 SBKP     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 6           18:40:00                    0
# 7           12:30:00                    3
# 8           23:15:00                    2
# 15          21:22:00                    0
# 20          19:32:00                    0
# ...              ...                  ...
# 5661        22:39:00                    0
# 5663        14:20:00                    0
# 5680        22:00:00                    0
# 5696        12:50:00                    0
# 5747        19:00:00                    0
#
# [825 rows x 9 columns]

# %%
#ocorrencia cuja cidade terminem com a letra A
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 12            BRAS�LIA            DF                 SBBR     2010-01-10
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 25          UBERL�NDIA            MG                  NaN     2010-01-20
# 26            SOROCABA            SP                  NaN     2010-01-20
# ...                ...           ...                  ...            ...
# 5738         FORTALEZA            CE                 SBFZ     2020-12-23
# 5739          MARITUBA            PA                  NaN     2020-12-26
# 5743     RIO PARANA�BA            MG                 SNRP     2020-12-28
# 5744          GOIATUBA            GO                  NaN     2020-12-29
# 5750         VICENTINA            MS                  NaN     2020-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 12          03:00:00                    0
# 15          21:22:00                    0
# 25          18:58:00                    0
# 26          13:10:00                    0
# ...              ...                  ...
# 5738        18:30:00                    0
# 5739        12:05:00                    0
# 5743        17:00:00                    0
# 5744        12:00:00                    0
# 5750        09:00:00                    0
#
# [1556 rows x 9 columns]

# %%
#ocorrencia cuja cidade terminem com a silaba MA
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2655              51347               51347                INCIDENTE
# 2855              52340               52340                 ACIDENTE
# 2966              52832               52832                 ACIDENTE
# 2997              52979               52979                 ACIDENTE
# 3040              52984               52984                 ACIDENTE
# 3092              53596               53596                INCIDENTE
# 3157              53223               53223                 ACIDENTE
# 3171              53265               53265                 ACIDENTE
# 3189              53271               53271          INCIDENTE GRAVE
# 3682              65414               65414          INCIDENTE GRAVE
# 3725              65633               65633          INCIDENTE GRAVE
# 3881              66265               66265                 ACIDENTE
# 4229              77371               77371                 ACIDENTE
# 4311              77612               77612                 ACIDENTE
# 4574              78080               78080                 ACIDENTE
# 4986              78867               78867                INCIDENTE
# 5070              78923               78923          INCIDENTE GRAVE
# 5080              78782               78782                 ACIDENTE
# 5405              79282               79282                 ACIDENTE
# 5440              79338               79338                INCIDENTE
# 5474              79400               79400                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 15            CANUTAMA            AM                  NaN     2010-01-15
# 408          NOVO GAMA            GO                  NaN     2010-09-25
# 688           BURITAMA            SP                  NaN     2011-03-19
# 1035          BURITAMA            SP                 SIBX     2011-10-25
# 1377          UMUARAMA            PR                  NaN     2012-05-30
# 1401         AURIFLAMA            SP                  NaN     2012-06-16
# 2099         NOVA LIMA            MG                  NaN     2013-06-15
# 2102          CANUTAMA            AM                  NaN     2013-06-18
# 2655           DIADEMA            SP                  NaN     2014-05-04
# 2855              FAMA            MG                  NaN     2014-09-20
# 2966          BURITAMA            SP                  NaN     2014-12-14
# 2997          IVINHEMA            MS                  NaN     2015-01-02
# 3040         NOVA LIMA            MG                 SJLY     2015-02-01
# 3092           ITAPEMA            SC                  NaN     2015-03-10
# 3157         PINDORAMA            SP                  NaN     2015-04-22
# 3171         PACARAIMA            RR                 SDMM     2015-05-05
# 3189          UMUARAMA            PR                  NaN     2015-05-17
# 3682         NOVA LIMA            MG                 SJLY     2016-07-08
# 3725         NOVA LIMA            MG                  NaN     2016-08-31
# 3881          BURITAMA            SP                  NaN     2017-01-13
# 4229          CANUTAMA            AM                 SDKH     2017-11-02
# 4311           ITAPEMA            SC                  NaN     2018-01-06
# 4574           ITAPEMA            SC                  NaN     2018-07-28
# 4986           IRACEMA            RR                  NaN     2019-07-06
# 5070          CANUTAMA            AM                  NaN     2019-09-03
# 5080          IVINHEMA            MS                  NaN     2019-09-08
# 5405           ITURAMA            MG                  NaN     2020-04-11
# 5440          IVINHEMA            MS                  NaN     2020-05-15
# 5474           IBIRAMA            SC                  NaN     2020-06-09
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 15          21:22:00                    0
# 408         16:30:00                    1
# 688         11:18:00                    0
# 1035        19:15:00                    0
# 1377        19:00:00                    0
# 1401        19:30:00                    0
# 2099        12:00:00                    4
# 2102        21:30:00                    0
# 2655        16:00:00                    0
# 2855        15:00:00                    1
# 2966        23:40:00                    0
# 2997        14:50:00                    0
# 3040        15:10:00                    0
# 3092        21:35:00                    0
# 3157        12:45:00                    0
# 3171        16:05:00                    2
# 3189        17:00:00                    0
# 3682        19:50:00                    1
# 3725        17:40:00                    0
# 3881        16:00:00                    0
# 4229        19:30:00                    1
# 4311        10:30:00                    0
# 4574        14:20:00                    0
# 4986        00:00:00                    0
# 5070        14:00:00                    0
# 5080        17:45:00                    0
# 5405        12:20:00                    0
# 5440        09:40:00                    0
# 5474        14:00:00                    0

# %%
#ocorrencia cuja cidade contem a silaba MA
filtro = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5732              79745               79745                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5741              79754               79754          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 13    PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 15              CANUTAMA            AM                  NaN     2010-01-15
# 35                PALMAS            TO                 SBPJ     2010-01-26
# 78                MANAUS            AM                 SBEG     2010-03-07
# ...                  ...           ...                  ...            ...
# 5732              MARAB�            PA                 SBMA     2020-12-21
# 5739            MARITUBA            PA                  NaN     2020-12-26
# 5741        NOVA MARING�            MT                  NaN     2020-12-28
# 5745           MATO RICO            PR                  NaN     2020-12-29
# 5746       MANOEL URBANO            AC                 SIMB     2020-12-29
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 13          17:00:00                    2
# 15          21:22:00                    0
# 35          16:50:00                    0
# 78          19:35:00                    2
# ...              ...                  ...
# 5732        08:47:00                    0
# 5739        12:05:00                    0
# 5741        13:00:00                    0
# 5745        10:30:00                    0
# 5746        18:30:00                    0
#
# [488 rows x 9 columns]

# %%
#ocorrencias do ano de 2015
filtro = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2996              52992               52992          INCIDENTE GRAVE
# 2997              52979               52979                 ACIDENTE
# 2998              53073               53073                INCIDENTE
# 2999              53074               53074                INCIDENTE
# 3000              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3462              60632               60632          INCIDENTE GRAVE
# 3463              60600               60600                INCIDENTE
# 3464              60642               60642                INCIDENTE
# 3465              60631               60631                 ACIDENTE
# 3466              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2996              SALVADOR            BA                 SBSV     2015-01-01
# 2997              IVINHEMA            MS                  NaN     2015-01-02
# 2998                  TEF�            AM                 SBTF     2015-01-02
# 2999        BELO HORIZONTE            MG                 SBBH     2015-01-02
# 3000                TOLEDO            PR                 SBTD     2015-01-04
# ...                    ...           ...                  ...            ...
# 3462               ITABER�            SP                  NaN     2015-12-24
# 3463             GUARULHOS            SP                 SBGR     2015-12-25
# 3464  S�O FRANCISCO DO SUL            SC                 SSSS     2015-12-26
# 3465             MA�AMBAR�            RS                  NaN     2015-12-28
# 3466            PORTO BELO            SC                 SDEN     2015-12-31
#
#      ocorrencia_hora  total_recomendacoes
# 2996        11:40:00                    3
# 2997        14:50:00                    0
# 2998        16:28:00                    0
# 2999        20:34:00                    0
# 3000        22:04:00                    6
# ...              ...                  ...
# 3462        14:00:00                    0
# 3463        19:00:00                    0
# 3464        16:00:00                    0
# 3465        19:00:00                    2
# 3466        14:00:00                    0
#
# [471 rows x 9 columns]

# %%
#ocorrencias do ano de 2015 e mês 12 e dia 8
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
filtro3 = df.ocorrencia_dia.dt.day == 8
df.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3436             AGUA�            SP                  NaN     2015-12-08
# 3437             JALES            SP                 SDJL     2015-12-08
# 3438          CAMPINAS            SP                 SBKP     2015-12-08
# 3439     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0

# %%
#ocorrencias do ano de 2015 e mês 12, do dia 3 ao dia 8
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
filtro3 = (df.ocorrencia_dia.dt.day > 2) & (df.ocorrencia_dia.dt.day < 9)
df.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# 3435              AMERICANA            SP                 SDAI     2015-12-06
# 3436                  AGUA�            SP                  NaN     2015-12-08
# 3437                  JALES            SP                 SDJL     2015-12-08
# 3438               CAMPINAS            SP                 SBKP     2015-12-08
# 3439          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3432        10:50:00                    0
# 3433        16:47:00                    0
# 3434        13:10:00                    3
# 3435        15:00:00                    1
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0

# %%
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BEL�M            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# 1        11:05:00                    0 2010-01-03 11:05:00
# 2        03:00:00                    0 2010-01-03 03:00:00
# 3        17:30:00                    0 2010-01-04 17:30:00
# 4        19:25:00                    0 2010-01-05 19:25:00

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
#ocorrencias do ano de 2015 e mês 12, do dia 3 ao dia 8
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro2 = df.ocorrencia_dia.dt.month == 12
filtro3 = (df.ocorrencia_dia.dt.day > 2) & (df.ocorrencia_dia.dt.day < 9)
df.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# 3435              AMERICANA            SP                 SDAI     2015-12-06
# 3436                  AGUA�            SP                  NaN     2015-12-08
# 3437                  JALES            SP                 SDJL     2015-12-08
# 3438               CAMPINAS            SP                 SBKP     2015-12-08
# 3439          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 3432        10:50:00                    0 2015-12-03 10:50:00
# 3433        16:47:00                    0 2015-12-03 16:47:00
# 3434        13:10:00                    3 2015-12-06 13:10:00
# 3435        15:00:00                    1 2015-12-06 15:00:00
# 3436        14:30:00                    1 2015-12-08 14:30:00
# 3437        10:20:00                    0 2015-12-08 10:20:00
# 3438        16:19:00                    0 2015-12-08 16:19:00
# 3439        13:00:00                    0 2015-12-08 13:00:00

# %%
filtro1 = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro2 = df.ocorrencia_dia_hora <= '2015-12-08 14:30:00'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3439              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3433    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434          TRINDADE            GO                  NaN     2015-12-06
# 3435         AMERICANA            SP                 SDAI     2015-12-06
# 3436             AGUA�            SP                  NaN     2015-12-08
# 3437             JALES            SP                 SDJL     2015-12-08
# 3439     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 3433        16:47:00                    0 2015-12-03 16:47:00
# 3434        13:10:00                    3 2015-12-06 13:10:00
# 3435        15:00:00                    1 2015-12-06 15:00:00
# 3436        14:30:00                    1 2015-12-08 14:30:00
# 3437        10:20:00                    0 2015-12-08 10:20:00
# 3439        13:00:00                    0 2015-12-08 13:00:00

# %%
#3ocorrencia do ano de 2015 e mes 03
filtro1 = df.ocorrencia_dia.dt.year == 2015
filtro = df.ocorrencia_dia.dt.month == 3
df201503 = df.loc[filtro & filtro2]
df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 77                40314               40314                INCIDENTE
# 78                39916               39916          INCIDENTE GRAVE
# 79                39910               39910                INCIDENTE
# 80                39887               39887                 ACIDENTE
# 81                39914               39914                INCIDENTE
# ...                 ...                 ...                      ...
# 3118              53212               53212                INCIDENTE
# 3119              53213               53213                INCIDENTE
# 3120              53181               53181                 ACIDENTE
# 3121              53187               53187                INCIDENTE
# 3122              53211               53211                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 77           S�O PAULO            SP                  NaN     2010-03-04
# 78              MANAUS            AM                 SBEG     2010-03-07
# 79           GUARULHOS            SP                 SBGR     2010-03-08
# 80      BELO HORIZONTE            MG                 SBPR     2010-03-09
# 81            LONDRINA            PR                 SBLO     2010-03-09
# ...                ...           ...                  ...            ...
# 3118           JUNDIA�            SP                 SBJD     2015-03-28
# 3119           JUNDIA�            SP                 SBJD     2015-03-28
# 3120           COL�DER            MT                  NaN     2015-03-29
# 3121         JOINVILLE            SC                 SBJV     2015-03-29
# 3122             BAURU            SP                 SBBU     2015-03-30
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 77          23:50:00                    0 2010-03-04 23:50:00
# 78          19:35:00                    2 2010-03-07 19:35:00
# 79          00:49:00                    0 2010-03-08 00:49:00
# 80          17:45:00                    1 2010-03-09 17:45:00
# 81          21:00:00                    0 2010-03-09 21:00:00
# ...              ...                  ...                 ...
# 3118        17:32:00                    0 2015-03-28 17:32:00
# 3119        15:51:00                    0 2015-03-28 15:51:00
# 3120        20:17:00                    0 2015-03-29 20:17:00
# 3121        18:36:00                    0 2015-03-29 18:36:00
# 3122        19:40:00                    0 2015-03-30 19:40:00
#
# [294 rows x 10 columns]

# %%
df201503.count()
# Out:
# codigo_ocorrencia           294
# codigo_ocorrencia2          294
# ocorrencia_classificacao    294
# ocorrencia_cidade           294
# ocorrencia_uf               294
# ocorrencia_aerodromo        170
# ocorrencia_dia              294
# ocorrencia_hora             294
# total_recomendacoes         294
# ocorrencia_dia_hora         294
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            81
# INCIDENTE          180
# INCIDENTE GRAVE     33
# Name: codigo_ocorrencia, dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            81
# INCIDENTE          180
# INCIDENTE GRAVE     33
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     33
# ACIDENTE            81
# INCIDENTE          180
# dtype: int64

# %%
df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          180
# ACIDENTE            81
# INCIDENTE GRAVE     33
# dtype: int64

# %%
filtro1 = df.ocorrencia_dia.dt.year == 2010
filtro2 = df.ocorrencia_uf.isin(['SP','MG','ES','RJ'])
dfsudeste2010 = df.loc[filtro1 & filtro2]
dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 9       PAR� DE MINAS            MG                  NaN     2010-01-10
# 11          S�O PAULO            SP                 SBMT     2010-01-10
# 16          S�O PAULO            SP                  NaN     2010-01-15
# ..                ...           ...                  ...            ...
# 541            CAJOBI            SP                  NaN     2010-12-23
# 544         S�O PAULO            SP                 SBSP     2010-12-26
# 548        COSM�POLIS            SP                  NaN     2010-12-29
# 550           VIT�RIA            ES                  NaN     2010-12-30
# 551   ARRAIAL DO CABO            RJ                  NaN     2010-12-30
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0          12:00:00                    0 2010-01-03 12:00:00
# 2          03:00:00                    0 2010-01-03 03:00:00
# 9          20:00:00                    0 2010-01-10 20:00:00
# 11         14:50:00                    8 2010-01-10 14:50:00
# 16         15:00:00                    0 2010-01-15 15:00:00
# ..              ...                  ...                 ...
# 541        11:00:00                    0 2010-12-23 11:00:00
# 544        22:10:00                    0 2010-12-26 22:10:00
# 548        12:00:00                    0 2010-12-29 12:00:00
# 550        18:10:00                    0 2010-12-30 18:10:00
# 551        14:28:00                    0 2010-12-30 14:28:00
#
# [228 rows x 10 columns]

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
dfsudeste2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# S�O PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACA�                    12
# CONFINS                   7
# UBERL�NDIA                5
# JUIZ DE FORA              4
# VIT�RIA                   4
# MAR�LIA                   3
# S�O JOS� DOS CAMPOS       3
# S�O JOS� DO RIO PRETO     3
# SOROCABA                  2
# ITANHA�M                  2
# RIBEIR�O PRETO            2
# IPATINGA                  2
# PO�OS DE CALDAS           2
# DIVIN�POLIS               2
# BAURU                     2
# JUNDIA�                   2
# ARARAQUARA                2
# CAMPOS DOS GOYTACAZES     2
# AREALVA                   2
# MONTES CLAROS             2
# UBERABA                   2
# POUSO ALEGRE              1
# PIRACICABA                1
# PIRASSUNUNGA              1
# ARRAIAL DO CABO           1
# RESENDE                   1
# PEN�POLIS                 1
# SANTOS                    1
# SERRA NEGRA               1
# S�O BERNARDO DO CAMPO     1
# TIM�TEO                   1
# ARA�ATUBA                 1
# PIACATU                   1
# BOM JESUS DO AMPARO       1
# PAR� DE MINAS             1
# OL�MPIA                   1
# BRAGAN�A PAULISTA         1
# BROTAS                    1
# CAJOBI                    1
# CAMANDUCAIA               1
# BOITUVA                   1
# CASIMIRO DE ABREU         1
# BOCAINA                   1
# COROMANDEL                1
# COSM�POLIS                1
# DIAMANTINA                1
# BEBEDOURO                 1
# IPER�                     1
# IT�POLIS                  1
# LINHARES                  1
# MANGARATIBA               1
# BOM JESUS DO GALHO        1
# NOVO HORIZONTE            1
# AMERICANA                 1
# dtype: int64

# %%
filtro1 = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
filtro2 = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro1 & filtro2].total_recomendacoes.sum()
# Out:
# 25

# %%
filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHA�M                  1
# BELO HORIZONTE            2
# S�O BERNARDO DO CAMPO     2
# IPER�                     3
# NOVO HORIZONTE            3
# TIM�TEO                   3
# JUNDIA�                   7
# RESENDE                   8
# BRAGAN�A PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# S�O PAULO                41
# Name: total_recomendacoes, dtype: int64

# %%
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# BELO HORIZONTE         2                  1
#                        3                  1
# BOITUVA                7                  1
# BOM JESUS DO GALHO     12                 1
# BRAGAN�A PAULISTA      11                 9
# CAMANDUCAIA            7                  9
# IPER�                  1                  3
# ITANHA�M               9                  1
# JUNDIA�                5                  5
#                        6                  2
# NOVO HORIZONTE         7                  3
# RESENDE                4                  8
# RIO DE JANEIRO         4                  3
#                        7                  3
#                        8                 19
# S�O BERNARDO DO CAMPO  1                  2
# S�O PAULO              1                  8
#                        2                 14
#                        6                  2
#                        11                 6
#                        12                11
# TIM�TEO                2                  3
# Name: total_recomendacoes, dtype: int64

# %%
filtro1 = dfsudeste2010.total_recomendacoes > 0 
filtro2 = dfsudeste2010.ocorrencia_cidade == 'S�O PAULO'
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11               40069               40069                 ACIDENTE
# 58               39275               39275                 ACIDENTE
# 63               39992               39992                 ACIDENTE
# 219              41411               41411          INCIDENTE GRAVE
# 469              43450               43450                 ACIDENTE
# 530              43471               43471                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 11          S�O PAULO            SP                 SBMT     2010-01-10
# 58          S�O PAULO            SP                  NaN     2010-02-10
# 63          S�O PAULO            SP                 SBMT     2010-02-17
# 219         S�O PAULO            SP                 SBMT     2010-06-08
# 469         S�O PAULO            SP                 SBMT     2010-11-04
# 530         S�O PAULO            SP                  NaN     2010-12-14
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 11         14:50:00                    8 2010-01-10 14:50:00
# 58         09:03:00                    3 2010-02-10 09:03:00
# 63         20:07:00                   11 2010-02-17 20:07:00
# 219        19:30:00                    2 2010-06-08 19:30:00
# 469        10:55:00                    6 2010-11-04 10:55:00
# 530        20:15:00                   11 2010-12-14 20:15:00
